# %% [markdown]
# # Matching IMDB to Wikipedia

# %%
import pandas as pd
import re
import ast
import numpy as np
from rapidfuzz import process, fuzz

# %%
wiki_movies = pd.read_csv("clean_data//clean_wikipedia_franchises.csv", index_col = 0)
imdb_movies = pd.read_csv("raw_data//imdb_movies_db.csv", index_col = 0)

# %% [markdown]
# We need to change the year for imdb_movies so it's an integer. We'll first remove any without a value (signified by \n) and then convert to int

# %%
imdb_movies = imdb_movies[~(imdb_movies["startYear"] == "\\N")]
imdb_movies["startYear"] = imdb_movies["startYear"].apply(lambda x: int(x))

# %% [markdown]
# Convert the akas from a string to a list:

# %%
def extract_akas(row):
    # convert string in list format to list
    if type(row) == str:
        akas = ast.literal_eval(row)
        return akas

# %%
imdb_movies["akas"] = imdb_movies["akas"].apply(lambda x : extract_akas(x))

# %%
imdb_movies[imdb_movies["primaryTitle"] == imdb_movies["originalTitle"]]
# Out:
#             tconst titleType                   primaryTitle  \
# 8        tt0000009     movie                     Miss Jerry
# 144      tt0000147     movie  The Corbett-Fitzsimmons Fight
# 498      tt0000502     movie                       Bohemios
# 570      tt0000574     movie    The Story of the Kelly Gang
# 610      tt0000615     movie             Robbery Under Arms
# ...            ...       ...                            ...
# 9849562  tt9916160     movie                     Drømmeland
# 9849575  tt9916190     movie                      Safeguard
# 9849614  tt9916270     movie       Il talento del calabrone
# 9849743  tt9916538     movie            Kuambil Lagi Hatiku
# 9849833  tt9916730     movie                         6 Gunn
#
#                          originalTitle  isAdult  startYear endYear  \
# 8                           Miss Jerry        0       1894      \N
# 144      The Corbett-Fitzsimmons Fight        0       1897      \N
# 498                           Bohemios        0       1905      \N
# 570        The Story of the Kelly Gang        0       1906      \N
# 610                 Robbery Under Arms        0       1907      \N
# ...                                ...      ...        ...     ...
# 9849562                     Drømmeland        0       2019      \N
# 9849575                      Safeguard        0       2020      \N
# 9849614       Il talento del calabrone        0       2020      \N
# 9849743            Kuambil Lagi Hatiku        0       2019      \N
# 9849833                         6 Gunn        0       2017      \N
#
#         runtimeMinutes                      genres  averageRating  numVotes  \
# 8                   45                     Romance            5.3     204.0
# 144                100      Documentary,News,Sport            5.3     469.0
# 498                100                          \N            4.1      15.0
# 570                 70  Action,Adventure,Biography            6.0     826.0
# 610                 \N                       Drama            4.3      24.0
# ...                ...                         ...            ...       ...
# 9849562             72                 Documentary            6.3      51.0
# 9849575             95   Action,Adventure,Thriller            3.7     242.0
# 9849614             84                    Thriller            5.8    1418.0
# 9849743            123                       Drama            8.6       7.0
# 9849833            116                          \N            8.3      10.0
#
#          akas                                          all_names
# 8        None                       [Fräulein Jerry, Miss Jerry]
# 144      None  [Бой Корбетта и Фитцсиммонса, The Corbett-Fitz...
# 498      None                                         [Bohemios]
# 570      None  [Die Geschichte der Kelly Bande, Priča o Kelij...
# 610      None                               [Robbery Under Arms]
# ...       ...                                                ...
# 9849562  None                                       [Drømmeland]
# 9849575  None                                        [Safeguard]
# 9849614  None  [Il talento del calabrone, Il calabrone, The t...
# 9849743  None                              [Kuambil Lagi Hatiku]
# 9849833  None                                    [6 Gunn, ६ गुण]
#
# [228642 rows x 13 columns]

# %% [markdown]
# Combine all the names into a new column

# %%
def combine_names(row):
    tempList = []
    tempList.append(row["primaryTitle"])
    tempList.append(row["originalTitle"])
    if isinstance(row["akas"], list):
        for x in row["akas"]:
            tempList.append(x)
    return tempList

imdb_movies["all_names"] = imdb_movies.apply(combine_names, axis=1)

# %% [markdown]
# Remove any duplicates in the all_names column

# %%
imdb_movies["all_names"] = imdb_movies["all_names"].apply(lambda x: list(set(x)))

# %%
imdb_movies = imdb_movies.explode("all_names")

# %% [markdown]
# ### Merge the dataframes

# %% [markdown]
# Now we're going to combine the dataframes in stages. Matching based on year and name first, then any with an exact name, not in the same year. We'll gradually reduce the dataframes in size by filtering to ensure we aren't matching ones that have already been matched.

# %% [markdown]
# These filters will ensure we're only keeping the columns we need

# %%
wiki_filter = ["tconst", "titleType", "primaryTitle","originalTitle", "isAdult","startYear","endYear","runtimeMinutes","genres","averageRating","numVotes","akas","_merge", "all_names"]
imdb_filter = ["franchise_name", "franchise_id", "movie_name", "release_year","_merge"]

# %% [markdown]
# # Adam, I need you to explain what's happening here. While I get it, I'm really struggling to formulate it into words in a way that makes sense

# %%
def filter_df(df, merge, cols):
    remainder = df[df["_merge"]== merge]
    remainder = remainder.drop(cols, axis = 1)
    return remainder

# %% [markdown]
# Combines the

# %%
all_merged = pd.merge(wiki_movies, imdb_movies, left_on=["movie_name", "release_year"], right_on=["all_names", "startYear"], how="outer", indicator = True)
wiki_remainder = filter_df(all_merged, "left_only", wiki_filter)
imdb_remainder = filter_df(all_merged, "right_only", imdb_filter)
all_merged[all_merged["_merge"]=="both"]
# Out:
#      franchise_id      franchise_name  \
# 0              f0  The Aldrich Family
# 1              f0  The Aldrich Family
# 2              f0  The Aldrich Family
# 3              f0  The Aldrich Family
# 4              f0  The Aldrich Family
# ...           ...                 ...
# 8152        f1344        Super Sentai
# 8157        f1344        Super Sentai
# 8158        f1344        Super Sentai
# 8171        f1344        Super Sentai
# 8174        f1344        Super Sentai
#
#                                              movie_name  release_year  \
# 0                                           What a Life        1939.0
# 1                                       Life with Henry        1940.0
# 2                           Henry Aldrich for President        1941.0
# 3                                 Henry Aldrich, Editor        1942.0
# 4                                       Henry and Dizzy        1942.0
# ...                                                 ...           ...
# 8152  Kamen Rider × Super Sentai × Space Sheriff: Su...        2013.0
# 8157      Ressha Sentai ToQger vs. Kyoryuger: The Movie        2015.0
# 8158                Super Hero Taisen GP: Kamen Rider 3        2015.0
# 8171  Kishiryu Sentai Ryusoulger Special Chapter: Me...        2021.0
# 8174                       Kaizoku Sentai: Ten Gokaiger        2021.0
#
#           tconst titleType                                       primaryTitle  \
# 0      tt0032123     movie                                        What a Life
# 1      tt0033834     movie                                    Life with Henry
# 2      tt0033708     movie                        Henry Aldrich for President
# 3      tt0034842     movie                              Henry Aldrich, Editor
# 4      tt0034844     movie                                    Henry and Dizzy
# ...          ...       ...                                                ...
# 8152   tt2632184     movie  Kamen Rider × Super Sentai × Space Sheriff: Su...
# 8157   tt4152148     movie      Ressha Sentai ToQger vs. Kyoryuger: The Movie
# 8158   tt4282466     movie                Super Hero Taisen GP: Kamen Rider 3
# 8171  tt13681618     movie  Kishiryu Sentai Ryusoulger Special Chapter: Me...
# 8174  tt14879560     movie                       Kaizoku Sentai: Ten Gokaiger
#
#                                           originalTitle  isAdult  startYear  \
# 0                                           What a Life      0.0     1939.0
# 1                                       Life with Henry      0.0     1940.0
# 2                           Henry Aldrich for President      0.0     1941.0
# 3                                 Henry Aldrich, Editor      0.0     1942.0
# 4                                       Henry and Dizzy      0.0     1942.0
# ...                                                 ...      ...        ...
# 8152  Kamen Raidâ × Sûpâ Sentai × Uchû Keiji: Supâ H...      0.0     2013.0
# 8157        Ressha Sentai Tokkyûjâ tai Kyôryûjâ Za Mûbî      0.0     2015.0
# 8158                Super Hero Taisen GP: Kamen Rider 3      0.0     2015.0
# 8171  Kishiryuu Sentai Ryuusoujâ Tokubetsuhen: Memor...      0.0     2021.0
# 8174                         Kaizoku Sentai Ten Gôkaijâ      0.0     2021.0
#
#      endYear runtimeMinutes                   genres  averageRating  numVotes  \
# 0         \N             75             Comedy,Drama            6.9      94.0
# 1         \N             80      Comedy,Family,Music            6.0      49.0
# 2         \N             75            Comedy,Family            6.6     146.0
# 3         \N             72      Comedy,Drama,Family            6.4     151.0
# 4         \N             71            Comedy,Family            7.2      58.0
# ...      ...            ...                      ...            ...       ...
# 8152      \N             92  Action,Adventure,Comedy            6.3     129.0
# 8157      \N             64                   Action            7.5      32.0
# 8158      \N             95                   Action            6.5      86.0
# 8171      \N             15           Action,Fantasy            6.4       6.0
# 8174      \N             61  Action,Adventure,Comedy            8.7      75.0
#
#       akas                                          all_names _merge
# 0     None                                        What a Life   both
# 1     None                                    Life with Henry   both
# 2     None                        Henry Aldrich for President   both
# 3     None                              Henry Aldrich, Editor   both
# 4     None                                    Henry and Dizzy   both
# ...    ...                                                ...    ...
# 8152  None  Kamen Rider × Super Sentai × Space Sheriff: Su...   both
# 8157  None      Ressha Sentai ToQger vs. Kyoryuger: The Movie   both
# 8158  None                Super Hero Taisen GP: Kamen Rider 3   both
# 8171  None  Kishiryu Sentai Ryusoulger Special Chapter: Me...   both
# 8174  None                       Kaizoku Sentai: Ten Gokaiger   both
#
# [4343 rows x 18 columns]

# %%
all_merged_both = all_merged[all_merged["_merge"]=="both"]
all_merged_both = all_merged_both.drop_duplicates(subset = "tconst",keep = "first")
all_merged_both
# Out:
#      franchise_id      franchise_name  \
# 0              f0  The Aldrich Family
# 1              f0  The Aldrich Family
# 2              f0  The Aldrich Family
# 3              f0  The Aldrich Family
# 4              f0  The Aldrich Family
# ...           ...                 ...
# 8152        f1344        Super Sentai
# 8157        f1344        Super Sentai
# 8158        f1344        Super Sentai
# 8171        f1344        Super Sentai
# 8174        f1344        Super Sentai
#
#                                              movie_name  release_year  \
# 0                                           What a Life        1939.0
# 1                                       Life with Henry        1940.0
# 8158  None                Super Hero Taisen GP: Kamen Rider 3   both
# 8171  None  Kishiryu Sentai Ryusoulger Special Chapter: Me...   both
# 8174  None                       Kaizoku Sentai: Ten Gokaiger   both
#
# [4229 rows x 18 columns]

# %%
Get any

# %%
imdb_remainder = imdb_remainder[~imdb_remainder["tconst"].isin(all_merged_both["tconst"])]

# %%
no_year = pd.merge(wiki_remainder, imdb_remainder, left_on=["movie_name"], right_on=["all_names"], how="outer", indicator = True)
wiki_remainder = filter_df(all_merged, "left_only", wiki_filter)
imdb_remainder = filter_df(all_merged, "right_only", imdb_filter)
no_year
# Out:
#        franchise_id franchise_name                           movie_name  \
# 0                f1     Coffin Joe      At Midnight I'll Take Your Soul
# 1                f1     Coffin Joe  This Night I'll Possess Your Corpse
# 2                f1     Coffin Joe                       The End of Man
# 3                f1     Coffin Joe    The Bloody Exorcism of Coffin Joe
# 4                f1     Coffin Joe                        Hellish Flesh
# ...             ...            ...                                  ...
# 352999          NaN            NaN                                  NaN
# 353000          NaN            NaN                                  NaN
# 353001          NaN            NaN                                  NaN
# 353002          NaN            NaN                                  NaN
# 353003          NaN            NaN                                  NaN
#
#         release_year     tconst titleType              primaryTitle  \
# 0             1963.0        NaN       NaN                       NaN
# 1             1967.0        NaN       NaN                       NaN
# 2             1970.0        NaN       NaN                       NaN
# 3             1974.0        NaN       NaN                       NaN
# 4             1977.0        NaN       NaN                       NaN
# ...              ...        ...       ...                       ...
# 352999           NaN  tt9916270     movie  Il talento del calabrone
# 353000           NaN  tt9916428     movie       The Secret of China
# 353001           NaN  tt9916428     movie       The Secret of China
# 353002           NaN  tt9916538     movie       Kuambil Lagi Hatiku
# 353003           NaN  tt9916730     movie                    6 Gunn
#
#                        originalTitle  isAdult  startYear endYear  \
# 0                                NaN      NaN        NaN     NaN
# 1                                NaN      NaN        NaN     NaN
# 2                                NaN      NaN        NaN     NaN
# 3                                NaN      NaN        NaN     NaN
# 4                                NaN      NaN        NaN     NaN
# ...                              ...      ...        ...     ...
# 352999      Il talento del calabrone      0.0     2020.0      \N
# 353000  Hong xing zhao yao Zhong guo      0.0     2019.0      \N
# 353001  Hong xing zhao yao Zhong guo      0.0     2019.0      \N
# 353002           Kuambil Lagi Hatiku      0.0     2019.0      \N
# 353003                        6 Gunn      0.0     2017.0      \N
#
#        runtimeMinutes                 genres  averageRating  numVotes  akas  \
# 0                 NaN                    NaN            NaN       NaN   NaN
# 1                 NaN                    NaN            NaN       NaN   NaN
# 2                 NaN                    NaN            NaN       NaN   NaN
# 3                 NaN                    NaN            NaN       NaN   NaN
# 4                 NaN                    NaN            NaN       NaN   NaN
# ...               ...                    ...            ...       ...   ...
# 352999             84               Thriller            5.8    1418.0  None
# 353000             \N  Adventure,History,War            3.8      14.0  None
# 353001             \N  Adventure,History,War            3.8      14.0  None
# 353002            123                  Drama            8.6       7.0  None
# 353003            116                     \N            8.3      10.0  None
#
#                            all_names      _merge
# 0                                NaN   left_only
# 1                                NaN   left_only
# 2                                NaN   left_only
# 3                                NaN   left_only
# 4                                NaN   left_only
# ...                              ...         ...
# 352999      Il talento del calabrone  right_only
# 353000  Hong xing zhao yao Zhong guo  right_only
# 353001           The Secret of China  right_only
# 353002           Kuambil Lagi Hatiku  right_only
# 353003                        6 Gunn  right_only
#
# [353004 rows x 18 columns]

# %%
no_year_both = no_year[no_year["_merge"]=="both"]
no_year_both = no_year_both.drop_duplicates(subset = "tconst",keep = "first")
no_year_both["tconst"].nunique()
# Out:
# 674

# %%
no_year_both['difference_in_years'] = no_year_both.apply(lambda x: abs(x['startYear'] - x['release_year']), axis=1)
no_year_both = no_year_both[no_year_both["difference_in_years"] <= 10]
no_year_both["tconst"].nunique()
# Out:
# 346

# %%
no_year_both.head(50)
# Out:
#     franchise_id                                     franchise_name  \
# 77           f16                                Young and Dangerous
# 78           f16                                Young and Dangerous
# 79           f16                                Young and Dangerous
# 119          f20                                             Gamera
# 132          f23  L.E.T.H.A.L. Ladies (a.k.a. Triple-B, Bullets,...
# 152          f27                          Signed, Sealed, Delivered
# 154          f27                          Signed, Sealed, Delivered
# 155          f27                          Signed, Sealed, Delivered
# 159          f27                          Signed, Sealed, Delivered
# 163          f27                          Signed, Sealed, Delivered
# 164          f27                          Signed, Sealed, Delivered
# 241          f39                              American Film Theatre
# 242          f39                              American Film Theatre
# 246          f41                                              Darna
# 249          f41                                              Darna
# 257          f42                                     FIFA World Cup
# 258          f42                                     FIFA World Cup
# 259          f42                                     FIFA World Cup
# 260          f42                                     FIFA World Cup
# 261          f42                                     FIFA World Cup
# 262          f42                                     FIFA World Cup
# 263          f42                                     FIFA World Cup
# 265          f42                                     FIFA World Cup
# 280          f42                                     FIFA World Cup
# 281          f42                                     FIFA World Cup
# 320          f46                                          One Piece
# 321          f46                                          One Piece
# 324          f46                                          One Piece
# 325          f47                 Sherlock Holmes (1939 film series)
# 326          f47                 Sherlock Holmes (1939 film series)
# 336          f52                                        Philo Vance
# 396          f57                         DC Animated Movie Universe
# 397          f57                         DC Animated Movie Universe
# 398          f57                         DC Animated Movie Universe
# 399          f57                         DC Animated Movie Universe
# 400          f57                         DC Animated Movie Universe
# 401          f57                         DC Animated Movie Universe
# 404          f59                                         The Falcon
# 408          f60                                Garage Sale Mystery
# 423          f61                 Jungle Jim with Johnny Weissmuller
# 432          f63                                   Old Mother Riley
# 435          f63                                   Old Mother Riley
# 461          f67                                         Witchcraft
# 477          f68                                         Andy Hardy
# 491          f69            Jetlag Productions' Children's Classics
# 495          f69            Jetlag Productions' Children's Classics
# 497          f69            Jetlag Productions' Children's Classics
# 498          f69            Jetlag Productions' Children's Classics
# 502          f69            Jetlag Productions' Children's Classics
# 520          f69            Jetlag Productions' Children's Classics
#
#                                 movie_name  release_year      tconst  \
# 77                     Those Were the Days        2000.0   tt0114146
# 78                     Those Were the Days        2000.0   tt0118165
# 79                     Those Were the Days        2000.0   tt0285244
# 119                       Gamera the Brave        2006.0   tt0467923
# 132                            Hard Hunted        1992.0   tt0104391
Doubutsu Sentai Zyuohger vs. Ninninger the Mov...        2016.0
#
#          tconst titleType                                       primaryTitle  \
# 0     tt0032123     movie                                        What a Life
# 1     tt0033834     movie                                    Life with Henry
# 2     tt0033708     movie                        Henry Aldrich for President
# 3     tt0034842     movie                              Henry Aldrich, Editor
# 4     tt0034844     movie                                    Henry and Dizzy
# ...         ...       ...                                                ...
# 4097  tt0023539     movie                                       Sunset Trail
# 4098  tt0030812     movie                                       Sunset Trail
# 4100  tt0034996     movie                                        Lost Canyon
# 4102  tt0038532     movie                                        Fool's Gold
# 4152  tt6342418     movie  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...
#
#                                           originalTitle  isAdult  startYear  \
# 0                                           What a Life      0.0     1939.0
# 1                                       Life with Henry      0.0     1940.0
# 2                           Henry Aldrich for President      0.0     1941.0
# 3                                 Henry Aldrich, Editor      0.0     1942.0
# 4                                       Henry and Dizzy      0.0     1942.0
# ...                                                 ...      ...        ...
# 4097                                       Sunset Trail      0.0     1932.0
# 4098                                       Sunset Trail      0.0     1938.0
# 4100                                        Lost Canyon      0.0     1942.0
# 4102                                        Fool's Gold      0.0     1946.0
# 4152  Gekijôban Dôbutsu Sentai Jûôjâ Tai Ninninjâ Mi...      0.0     2017.0
#
#      endYear runtimeMinutes                genres  averageRating  numVotes  \
# 0         \N             75          Comedy,Drama            6.9      94.0
# 1         \N             80   Comedy,Family,Music            6.0      49.0
# 2         \N             75         Comedy,Family            6.6     146.0
# 3         \N             72   Comedy,Drama,Family            6.4     151.0
# 4         \N             71         Comedy,Family            7.2      58.0
# ...      ...            ...                   ...            ...       ...
# 4097      \N             62  Action,Music,Romance            6.2      42.0
# 4098      \N             69         Drama,Western            6.9     182.0
# 4100      \N             61         Drama,Western            6.2     163.0
# 4102      \N             63         Drama,Western            6.1     140.0
# 4152      \N             64                Action            6.9      35.0
#
#       akas                                          all_names _merge  \
# 0     None                                        What a Life   both
# 1     None                                    Life with Henry   both
# 2     None                        Henry Aldrich for President   both
# 3     None                              Henry Aldrich, Editor   both
# 4     None                                    Henry and Dizzy   both
# ...    ...                                                ...    ...
# 4097  None                                       Sunset Trail   both
# 4098  None                                       Sunset Trail   both
# 4100  None                                        Lost Canyon   both
# 4102  None                                        Fool's Gold   both
# 4152  None  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...   both
#
#       difference_in_years
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 4097                  7.0
# 4098                  1.0
# 4100                  1.0
# 4102                  1.0
# 4152                  1.0
#
# [4575 rows x 19 columns]

# %%
imdb_remainder = imdb_remainder[~imdb_remainder["tconst"].isin(all_merged_both["tconst"])]

# %%
def get_top_match(row):
    return process.extractOne(row.movie_name, imdb_movie_list)

# %%
imdb_movie_list = imdb_remainder.all_names.to_list()

# %%
wiki_remainder['best_match'] = wiki_remainder.apply(lambda row: get_top_match(row), axis = 1)

# %%
matched = matched[["franchise_id", "franchise_name", "movie_name", "tconst", "primaryTitle", "isAdult", "release_year", "runtimeMinutes", "genres", "averageRating", "numVotes"]]

# %%
matched
# Out:
#      franchise_id                       franchise_name  \
# 0              f0                   The Aldrich Family
# 1              f0                   The Aldrich Family
# 2              f0                   The Aldrich Family
# 3              f0                   The Aldrich Family
# 4              f0                   The Aldrich Family
# ...           ...                                  ...
# 4097        f1343  Hopalong Cassidy (American-Western)
# 4098        f1343  Hopalong Cassidy (American-Western)
# 4100        f1343  Hopalong Cassidy (American-Western)
# 4102        f1343  Hopalong Cassidy (American-Western)
# 4152        f1344                         Super Sentai
#
#                                              movie_name     tconst  \
# 0                                           What a Life  tt0032123
# 1                                       Life with Henry  tt0033834
# 2                           Henry Aldrich for President  tt0033708
# 3                                 Henry Aldrich, Editor  tt0034842
# 4                                       Henry and Dizzy  tt0034844
# ...                                                 ...        ...
# 4097                                       Sunset Trail  tt0023539
# 4098                                       Sunset Trail  tt0030812
# 4100                                        Lost Canyon  tt0034996
# 4102                                        Fool's Gold  tt0038532
# 4152  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...  tt6342418
#
#                                            primaryTitle  isAdult  \
# 0                                           What a Life      0.0
# 1                                       Life with Henry      0.0
# 2                           Henry Aldrich for President      0.0
# 3                                 Henry Aldrich, Editor      0.0
# 4                                       Henry and Dizzy      0.0
# ...                                                 ...      ...
# 4097                                       Sunset Trail      0.0
# 4098                                       Sunset Trail      0.0
# 4100                                        Lost Canyon      0.0
# 4102                                        Fool's Gold      0.0
# 4152  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...      0.0
#
#       release_year runtimeMinutes                genres  averageRating  \
# 0           1939.0             75          Comedy,Drama            6.9
# 1           1940.0             80   Comedy,Family,Music            6.0
# 2           1941.0             75         Comedy,Family            6.6
# 3           1942.0             72   Comedy,Drama,Family            6.4
# 4           1942.0             71         Comedy,Family            7.2
# ...            ...            ...                   ...            ...
# 4097        1939.0             62  Action,Music,Romance            6.2
# 4098        1939.0             69         Drama,Western            6.9
# 4100        1943.0             61         Drama,Western            6.2
# 4102        1947.0             63         Drama,Western            6.1
# 4152        2016.0             64                Action            6.9
#
#       numVotes
# 0         94.0
# 1         49.0
# 2        146.0
# 3        151.0
# 4         58.0
# ...        ...
# 4097      42.0
# 4098     182.0
# 4100     163.0
# 4102     140.0
# 4152      35.0
#
# [4575 rows x 11 columns]

# %%
wiki_remainder
# Out:
#      franchise_id franchise_name  \
# 11             f1     Coffin Joe
# 12             f1     Coffin Joe
# 15             f1     Coffin Joe
# 16             f1     Coffin Joe
# 18             f1     Coffin Joe
# ...           ...            ...
# 8175        f1344   Super Sentai
# 8176        f1344   Super Sentai
# 8177        f1344   Super Sentai
# 8178        f1344   Super Sentai
# 8179        f1344   Super Sentai
#
#                                              movie_name  release_year  \
# 11                      At Midnight I'll Take Your Soul        1963.0
# 12                  This Night I'll Possess Your Corpse        1967.0
# 15                                       The End of Man        1970.0
# 16                    The Bloody Exorcism of Coffin Joe        1974.0
# 18                                        Hellish Flesh        1977.0
# ...                                                 ...           ...
# 8175  Kikai Sentai Zenkaiger vs. Kiramager vs. Senpa...        2022.0
# 8176  Avataro Sentai Donbrothers The Movie: New Firs...        2022.0
# 8177  Ninpu Sentai Hurricaneger Degozaru! Shushuuto ...        2023.0
# 8178           Avataro Sentai Donbrothers vs. Zenkaiger        2023.0
# 8179  Bakuryuu Sentai Abaranger 20th: The Unforgivab...        2023.0
#
#                                              best_match
# 11                               (Midnight, 90.0, 7465)
# 12                                 (Posse, 90.0, 46642)
# 15          (The End of Men, 92.85714285714286, 244599)
# 16                                 (Blood, 90.0, 44667)
# 18                                  (Flesh, 90.0, 5828)
# ...                                                 ...
# 8175  (Kikai Sentai Zenkaiger vs Kiramager vs Senpai...
# 8176                             (Brothers, 90.0, 4072)
# 8177                            (Hurricane, 90.0, 4688)
# 8178                             (Brothers, 90.0, 4072)
# 8179                        (Unforgivable, 90.0, 89858)
#
# [3837 rows x 5 columns]

# %%
matched.columns = matched.columns.str.replace('release_year', 'startYear')

# %%
imdb_final = pd.merge(matched, imdb_movies, on = "tconst", how = "outer")
imdb_final

# %%
imdb_final = imdb_final[["index", "franchise_id", "franchise_name", "movie_name", "tconst", "primaryTitle_y", "isAdult_y", "startYear_y", "runtimeMinutes_y", "genres_y", "averageRating_y", "numVotes_y"]]
imdb_final

# %%
imdb_final.columns = imdb_final.columns.str.replace('primaryTitle_y', 'primaryTitle')
imdb_final.columns = imdb_final.columns.str.replace('isAdult_y', 'isAdult')
imdb_final.columns = imdb_final.columns.str.replace('startYear_y', 'startYear')
imdb_final.columns = imdb_final.columns.str.replace('runtimeMinutes_y', 'runtimeMinutes')
imdb_final.columns = imdb_final.columns.str.replace('genres_y', 'genres')
imdb_final.columns = imdb_final.columns.str.replace('averageRating_y', 'averageRating')
imdb_final.columns = imdb_final.columns.str.replace('numVotes_y', 'numVotes')

# %%
wiki_remainder["franchise_name"].unique()

# %%
imdb_final.to_csv("movies_with_franchises.csv")

# %%
imdb_final["franchise_id"].nunique()

# %% [markdown]
# # Test Code

# %%
imdb_final[imdb_final["primaryTitle"] == "iron man"]

# %%
wiki_remainder[wiki_remainder["franchise_name"] == "DC Extended Universe"]

# %%
test = imdb_remainder.sort_values("numVotes", ascending = False).drop_duplicates(subset=["tconst"], keep="first").sort_values(["tconst"])
test[test["numVotes"] >292]

# %%
imdb_final[imdb_final["franchise_id"].isnull]

# %%
test = pd.isnull(imdb_final["franchise_id"])
imdb_final[test]["numVotes"].describe()

# %%
test = pd.notnull(imdb_final["franchise_id"])
imdb_final[test]["numVotes"].describe()

# %% [markdown]
# # Unused code

# %%
# apply this mask function at each step of the matching process and see how many found rows there are
list1 = list(matched["index"])
found_mask = []
for i in range(0, len(list(wiki_movies["index"]))):
    if i in list1:
        found_mask.append(True)
    else:
        found_mask.append(False)
    
#print(list1)
print(wiki_movies[found_mask])

# %%
both_test = matched[matched["_merge"]=="both"].sort_values(by = "index")

# %%
# look into moving all names into one list, then searching with date
# With remainder, search without date and see what happens

# %%
# losing some values in both data frames for unknown reason when using merge.
# starts with 6405 rows in wiki and 290239 rows in imdb
# 3307 
#              wiki  |  imdb 
# start     |  6405  |  290239
# found     |  3088  |    3088
# remaining |  3307  |  287199
# total     |  6395  |  290287
# variance  |   -10  |     +48
