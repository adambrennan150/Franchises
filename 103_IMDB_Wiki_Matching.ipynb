# %% [markdown]
# # Matching IMDB to Wikipedia

# %% [markdown]
# This notebook will focus on merging our Wikipedia dataframe with the movies from our dataframe gathered from IMDB.
# - The first step is getting all movies that match in both dataframes with title and year.
# - The second step is to account for any movies where the title matches but the years are skewed somewhat, potentially by user error.
# - The final step is to fuzzymatch for for movies where the titles are not the same, due to small conflicts like ":" instead of "-".*
#
# *As such the threshold for the matching is very high, we are not trying to find the best fit for all remaining movies.

# %%
import pandas as pd
import re
import ast
import numpy as np
from rapidfuzz import process, fuzz

# %%
wiki_movies = pd.read_csv("wikipedia_movie_franchises.csv", index_col = 0)
imdb_movies = pd.read_csv("imdb_movies_db.csv", index_col = 0)

# %% [markdown]
# We need to change the year for imdb_movies so it's an integer. We'll first remove any without a value (signified by \n) and then convert to int

# %%
imdb_movies = imdb_movies[~(imdb_movies["startYear"] == "\\N")]
imdb_movies["startYear"] = imdb_movies["startYear"].apply(lambda x: int(x))

# %% [markdown]
# Convert the akas from a string to a list:

# %%
def extract_akas(row):
    # convert string in list format to list
    if type(row) == str:
        akas = ast.literal_eval(row)
        return akas

# %%
imdb_movies["akas"] = imdb_movies["akas"].apply(lambda x : extract_akas(x))

# %% [markdown]
# Combine all the names into a new column

# %%
def combine_names(row):
    tempList = []
    tempList.append(row["primaryTitle"])
    tempList.append(row["originalTitle"])
    if isinstance(row["akas"], list):
        for x in row["akas"]:
            tempList.append(x)
    return tempList

imdb_movies["all_names"] = imdb_movies.apply(combine_names, axis=1)

# %% [markdown]
# Remove any duplicates in the all_names column

# %%
imdb_movies["all_names"] = imdb_movies["all_names"].apply(lambda x: list(set(x)))

# %% [markdown]
# Create a row for each item in "all_names", to allow our matching to run through the dataframe smoothly, instead of going into each list in each row and checking them there.

# %%
imdb_movies = imdb_movies.explode("all_names")

# %% [markdown]
# ### Merge the dataframes

# %% [markdown]
# Now we're going to combine the dataframes in stages. Matching based on year and name first, then any with an exact name, with an offset in place for year to allow for any user error in IMDB and Wikipedia. We'll gradually reduce the dataframes in size by filtering to ensure we aren't matching ones that have already been matched.

# %%
wiki_filter = ["tconst", "titleType", "primaryTitle","originalTitle", "isAdult","startYear","endYear","runtimeMinutes","genres","averageRating","numVotes","akas","_merge", "all_names"]
imdb_filter = ["franchise_name", "franchise_id", "movie_name", "release_year","_merge"]

# %% [markdown]
# As the matching takes place, we merge both of our datasets. To get the unmatched rows for both dataframes, we apply this filter to the rows that were "left_only" or "right_only" in the "_merge" column, and return them as remainder dataframes.

# %%
def filter_df(df, merge, cols):
    remainder = df[df["_merge"]== merge]
    remainder = remainder.drop(cols, axis = 1)
    return remainder

# %% [markdown]
# Merges the dataframes based on title and year, then returns the unmatched rows for both dataframes.

# %%
all_merged = pd.merge(wiki_movies, imdb_movies, left_on=["movie_name", "release_year"], right_on=["all_names", "startYear"], how="outer", indicator = True)
wiki_remainder = filter_df(all_merged, "left_only", wiki_filter)
imdb_remainder = filter_df(all_merged, "right_only", imdb_filter)
all_merged
# Out:
#         franchise_id      franchise_name                   movie_name  \
# 0                 f0  The Aldrich Family                  What a Life
# 1                 f0  The Aldrich Family              Life with Henry
# 2                 f0  The Aldrich Family  Henry Aldrich for President
# 3                 f0  The Aldrich Family        Henry Aldrich, Editor
# 4                 f0  The Aldrich Family              Henry and Dizzy
# ...              ...                 ...                          ...
# 1340959          NaN                 NaN                          NaN
# 1340960          NaN                 NaN                          NaN
# 1340961          NaN                 NaN                          NaN
# 1340962          NaN                 NaN                          NaN
# 1340963          NaN                 NaN                          NaN
#
#          release_year     tconst titleType                 primaryTitle  \
# 0              1939.0  tt0032123     movie                  What a Life
# 1              1940.0  tt0033834     movie              Life with Henry
# 2              1941.0  tt0033708     movie  Henry Aldrich for President
# 3              1942.0  tt0034842     movie        Henry Aldrich, Editor
# 4              1942.0  tt0034844     movie              Henry and Dizzy
# ...               ...        ...       ...                          ...
# 1340959           NaN  tt9916428     movie          The Secret of China
# 1340960           NaN  tt9916428     movie          The Secret of China
# 1340961           NaN  tt9916538     movie          Kuambil Lagi Hatiku
# 1340962           NaN  tt9916730     movie                       6 Gunn
# 1340963           NaN  tt9916730     movie                       6 Gunn
#
#                         originalTitle  isAdult  startYear endYear  \
# 0                         What a Life      0.0     1939.0      \N
# 1                     Life with Henry      0.0     1940.0      \N
# 2         Henry Aldrich for President      0.0     1941.0      \N
# 3               Henry Aldrich, Editor      0.0     1942.0      \N
# 4                     Henry and Dizzy      0.0     1942.0      \N
# ...                               ...      ...        ...     ...
# 1340959  Hong xing zhao yao Zhong guo      0.0     2019.0      \N
# 1340960  Hong xing zhao yao Zhong guo      0.0     2019.0      \N
# 1340961           Kuambil Lagi Hatiku      0.0     2019.0      \N
# 1340962                        6 Gunn      0.0     2017.0      \N
# 1340963                        6 Gunn      0.0     2017.0      \N
#
#         runtimeMinutes                 genres  averageRating  numVotes  \
# 0                   75           Comedy,Drama            6.9      93.0
# 1                   80    Comedy,Family,Music            6.0      49.0
# 2                   75          Comedy,Family            6.6     146.0
# 3                   72    Comedy,Drama,Family            6.4     150.0
# 4                   71          Comedy,Family            7.2      58.0
# ...                ...                    ...            ...       ...
# 1340959             \N  Adventure,History,War            3.8      14.0
# 1340960             \N  Adventure,History,War            3.8      14.0
# 1340961            123                  Drama            8.6       7.0
# 1340962            116                     \N            8.3      10.0
# 1340963            116                     \N            8.3      10.0
#
#                                                       akas  \
# 0                      [What a Life, A Vida Começa aos 14]
# 1        [Life with Henry, Henry quería ir a Alaska, He...
# 2        [Henry Aldrich Para Presidente, Henry Aldrich ...
# 3                [Henry periodista, Henry Aldrich, Editor]
# 4                                        [Henry and Dizzy]
# ...                                                    ...
# 1340959  [The Secret of China, Hong xing zhao yao Zhong...
# 1340960  [The Secret of China, Hong xing zhao yao Zhong...
# 1340961                              [Kuambil Lagi Hatiku]
# 1340962                                    [६ गुण, 6 Gunn]
# 1340963                                    [६ गुण, 6 Gunn]
#
#                             all_names      _merge
# 0                         What a Life        both
# 1                     Life with Henry        both
# 2         Henry Aldrich for President        both
# 3               Henry Aldrich, Editor        both
# 4                     Henry and Dizzy        both
# ...                               ...         ...
# 1340959           The Secret of China  right_only
# 1340960  Hong xing zhao yao Zhong guo  right_only
# 1340961           Kuambil Lagi Hatiku  right_only
# 1340962                         ६ गुण  right_only
# 1340963                        6 Gunn  right_only
#
# [1340964 rows x 18 columns]

# %% [markdown]
# Drops any duplicate rows, as the cell may match more than one title in imdb if for example their primaryTitle or originalTitle are the same

# %%
all_merged_both = all_merged[all_merged["_merge"]=="both"]
all_merged_both = all_merged_both.drop_duplicates(subset = "tconst",keep = "first")
all_merged_both
# Out:
#      franchise_id      franchise_name  \
# 0              f0  The Aldrich Family
# 1              f0  The Aldrich Family
# 2              f0  The Aldrich Family
# 3              f0  The Aldrich Family
# 4              f0  The Aldrich Family
# ...           ...                 ...
# 8194        f1343        Super Sentai
# 8199        f1343        Super Sentai
# 8200        f1343        Super Sentai
# 8213        f1343        Super Sentai
# 8216        f1343        Super Sentai
#
#                                              movie_name  release_year  \
# 0                                           What a Life        1939.0
# 1                                       Life with Henry        1940.0
# 2                           Henry Aldrich for President        1941.0
# 3                                 Henry Aldrich, Editor        1942.0
# 4                                       Henry and Dizzy        1942.0
# ...                                                 ...           ...
# 8194  Kamen Rider × Super Sentai × Space Sheriff: Su...        2013.0
# 8199      Ressha Sentai ToQger vs. Kyoryuger: The Movie        2015.0
# 8200                Super Hero Taisen GP: Kamen Rider 3        2015.0
# 8213  Kishiryu Sentai Ryusoulger Special Chapter: Me...        2021.0
# 8216                       Kaizoku Sentai: Ten Gokaiger        2021.0
#
#           tconst titleType                                       primaryTitle  \
# 0      tt0032123     movie                                        What a Life
# 1      tt0033834     movie                                    Life with Henry
# 2      tt0033708     movie                        Henry Aldrich for President
# 3      tt0034842     movie                              Henry Aldrich, Editor
# 4      tt0034844     movie                                    Henry and Dizzy
# ...          ...       ...                                                ...
# 8194   tt2632184     movie  Kamen Rider × Super Sentai × Space Sheriff: Su...
# 8199   tt4152148     movie      Ressha Sentai ToQger vs. Kyoryuger: The Movie
# 8200   tt4282466     movie                Super Hero Taisen GP: Kamen Rider 3
# 8213  tt13681618     movie  Kishiryu Sentai Ryusoulger Special Chapter: Me...
# 8216  tt14879560     movie                       Kaizoku Sentai: Ten Gokaiger
#
#                                           originalTitle  isAdult  startYear  \
# 0                                           What a Life      0.0     1939.0
# 1                                       Life with Henry      0.0     1940.0
# 2                           Henry Aldrich for President      0.0     1941.0
# 3                                 Henry Aldrich, Editor      0.0     1942.0
# 4                                       Henry and Dizzy      0.0     1942.0
# ...                                                 ...      ...        ...
# 8194  Kamen Raidâ × Sûpâ Sentai × Uchû Keiji: Supâ H...      0.0     2013.0
# 8199        Ressha Sentai Tokkyûjâ tai Kyôryûjâ Za Mûbî      0.0     2015.0
# 8200                Super Hero Taisen GP: Kamen Rider 3      0.0     2015.0
# 8213  Kishiryuu Sentai Ryuusoujâ Tokubetsuhen: Memor...      0.0     2021.0
# 8216                         Kaizoku Sentai Ten Gôkaijâ      0.0     2021.0
#
#      endYear runtimeMinutes                   genres  averageRating  numVotes  \
# 0         \N             75             Comedy,Drama            6.9      93.0
# 1         \N             80      Comedy,Family,Music            6.0      49.0
# 2         \N             75            Comedy,Family            6.6     146.0
# 3         \N             72      Comedy,Drama,Family            6.4     150.0
# 4         \N             71            Comedy,Family            7.2      58.0
# ...      ...            ...                      ...            ...       ...
# 8194      \N             92  Action,Adventure,Comedy            6.3     129.0
# 8199      \N             64                   Action            7.5      32.0
# 8200      \N             95                   Action            6.5      85.0
# 8213      \N             15           Action,Fantasy            6.4       6.0
# 8216      \N             61  Action,Adventure,Comedy            8.6      73.0
#
#                                                    akas  \
# 0                   [What a Life, A Vida Começa aos 14]
# 1     [Life with Henry, Henry quería ir a Alaska, He...
# 2     [Henry Aldrich Para Presidente, Henry Aldrich ...
# 3             [Henry periodista, Henry Aldrich, Editor]
# 4                                     [Henry and Dizzy]
# ...                                                 ...
# 8194  [Kamen Raidâ × Sûpâ Sentai × Uchû Keiji: Supâ ...
# 8199  [Ressha Sentai Tokkyûjâ tai Kyôryûjâ Za Mûbî, ...
# 8200  [Super Hero Taisen GP: Kamen Rider 3, スーパーヒーロー...
# 8213  [Kishiryuu Sentai Ryuusoujâ Tokubetsuhen: Memo...
# 8216  [Kaizoku Sentai Ten Gokaiger, Kaizoku Sentai T...
#
#                                               all_names _merge
# 0                                           What a Life   both
# 1                                       Life with Henry   both
# 2                           Henry Aldrich for President   both
# 3                                 Henry Aldrich, Editor   both
# 4                                       Henry and Dizzy   both
# ...                                                 ...    ...
# 8194  Kamen Rider × Super Sentai × Space Sheriff: Su...   both
# 8199      Ressha Sentai ToQger vs. Kyoryuger: The Movie   both
# 8200                Super Hero Taisen GP: Kamen Rider 3   both
# 8213  Kishiryu Sentai Ryusoulger Special Chapter: Me...   both
# 8216                       Kaizoku Sentai: Ten Gokaiger   both
#
# [4519 rows x 18 columns]

# %% [markdown]
# This removes any unmatched values from the imdb_remainder, removing any rows that had a match with one of their exploded values

# %%
imdb_remainder = imdb_remainder[~imdb_remainder["tconst"].isin(all_merged_both["tconst"])]

# %% [markdown]
# This next segment of cells extract any movies that match based purely on the title, then filter out the ones where the year in one is too far removed from the other. We set that offset at 10 years.

# %%
no_year = pd.merge(wiki_remainder, imdb_remainder, left_on=["movie_name"], right_on=["all_names"], how="outer", indicator = True)
wiki_remainder = filter_df(all_merged, "left_only", wiki_filter)
imdb_remainder = filter_df(all_merged, "right_only", imdb_filter)
no_year
# Out:
#         franchise_id                franchise_name  \
# 0                 f1                    Coffin Joe
# 1                 f1                    Coffin Joe
# 2                 f2                The Crime Club
# 3                 f3                Fast & Furious
# 4                 f4  Gingerdead Man vs. Evil Bong
# ...              ...                           ...
# 1274737          NaN                           NaN
# 1274738          NaN                           NaN
# 1274739          NaN                           NaN
# 1274740          NaN                           NaN
# 1274741          NaN                           NaN
#
#                               movie_name  release_year     tconst titleType  \
# 0        At Midnight I'll Take Your Soul        1963.0        NaN       NaN
# 1                         The End of Man        1970.0  tt0067099     movie
# 2                       The Last Express        1938.0  tt0037776     movie
# 3                                 Fast X        2023.0        NaN       NaN
# 4        Evil Bong 3D: The Wrath of Bong        2011.0        NaN       NaN
# ...                                  ...           ...        ...       ...
# 1274737                              NaN           NaN  tt9916428     movie
# 1274738                              NaN           NaN  tt9916428     movie
# 1274739                              NaN           NaN  tt9916538     movie
# 1274740                              NaN           NaN  tt9916730     movie
# 1274741                              NaN           NaN  tt9916730     movie
#
#                 primaryTitle                 originalTitle  isAdult  \
# 0                        NaN                           NaN      NaN
# 1              Finis Hominis                 Finis Hominis      0.0
# 2             The Hidden Eye                The Hidden Eye      0.0
# 3                        NaN                           NaN      NaN
# 4                        NaN                           NaN      NaN
# ...                      ...                           ...      ...
# 1274737  The Secret of China  Hong xing zhao yao Zhong guo      0.0
# 1274738  The Secret of China  Hong xing zhao yao Zhong guo      0.0
# 1274739  Kuambil Lagi Hatiku           Kuambil Lagi Hatiku      0.0
# 1274740               6 Gunn                        6 Gunn      0.0
# 1274741               6 Gunn                        6 Gunn      0.0
#
#          startYear endYear runtimeMinutes                 genres  \
# 0              NaN     NaN            NaN                    NaN
# 1           1971.0      \N             79   Comedy,Drama,Mystery
# 2           1945.0      \N             69   Action,Crime,Mystery
# 3              NaN     NaN            NaN                    NaN
# 4              NaN     NaN            NaN                    NaN
# ...            ...     ...            ...                    ...
# 1274737     2019.0      \N             \N  Adventure,History,War
# 1274738     2019.0      \N             \N  Adventure,History,War
# 1274739     2019.0      \N            123                  Drama
# 1274740     2017.0      \N            116                     \N
# 1274741     2017.0      \N            116                     \N
#
#          averageRating  numVotes  \
# 0                  NaN       NaN
# 1                  5.7     373.0
# 2                  6.2     397.0
# 3                  NaN       NaN
# 4                  NaN       NaN
# ...                ...       ...
# 1274737            3.8      14.0
# 1274738            3.8      14.0
# 1274739            8.6       7.0
# 1274740            8.3      10.0
# 1274741            8.3      10.0
#
#                                                       akas  \
# 0                                                      NaN
# 1        [End of man, The End of Man, Finis Hominis, En...
# 2        [The Hidden Eye, Perfume do Oriente, L'oeil ca...
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1274737  [The Secret of China, Hong xing zhao yao Zhong...
# 1274738  [The Secret of China, Hong xing zhao yao Zhong...
# 1274739                              [Kuambil Lagi Hatiku]
# 1274740                                    [६ गुण, 6 Gunn]
# 1274741                                    [६ गुण, 6 Gunn]
#
#                             all_names      _merge
# 0                                 NaN   left_only
# 1                      The End of Man        both
# 2                    The Last Express        both
# 3                                 NaN   left_only
# 4                                 NaN   left_only
# ...                               ...         ...
# 1274737           The Secret of China  right_only
# 1274738  Hong xing zhao yao Zhong guo  right_only
# 1274739           Kuambil Lagi Hatiku  right_only
# 1274740                         ६ गुण  right_only
# 1274741                        6 Gunn  right_only
#
# [1274742 rows x 18 columns]

# %%
no_year_both = no_year[no_year["_merge"]=="both"]
no_year_both = no_year_both.drop_duplicates(subset = "tconst",keep = "first")
no_year_both["tconst"].nunique()
# Out:
# 918

# %%
no_year_both['difference_in_years'] = no_year_both.apply(lambda x: abs(x['startYear'] - x['release_year']), axis=1)
no_year_both = no_year_both[no_year_both["difference_in_years"] <= 10]
no_year_both["tconst"].nunique()
# Out:
# 427

# %%
no_year_both.head(50)
# Out:
#     franchise_id                                     franchise_name  \
# 1             f1                                         Coffin Joe
# 2             f2                                     The Crime Club
# 78           f16                                Young and Dangerous
# 79           f16                                Young and Dangerous
# 80           f16                                Young and Dangerous
# 81           f16                                Young and Dangerous
# 397                                   Hush   both                  1.0
# 398                                   Hush   both                  1.0

# %% [markdown]
# This merges the offset year matches with the rest of the matches above

# %%
matched = pd.concat([all_merged_both, no_year_both])
matched = matched[matched["_merge"]=="both"]
matched
# Out:
#      franchise_id                       franchise_name  \
# 0              f0                   The Aldrich Family
# 1              f0                   The Aldrich Family
# 2              f0                   The Aldrich Family
# 3              f0                   The Aldrich Family
# 4              f0                   The Aldrich Family
# ...           ...                                  ...
# 4040        f1342  Hopalong Cassidy (American-Western)
# 4041        f1342  Hopalong Cassidy (American-Western)
# 4043        f1342  Hopalong Cassidy (American-Western)
# 4046        f1342  Hopalong Cassidy (American-Western)
# 4096        f1343                         Super Sentai
#
#                                              movie_name  release_year  \
# 0                                           What a Life        1939.0
# 1                                       Life with Henry        1940.0
# 2                           Henry Aldrich for President        1941.0
# 3                                 Henry Aldrich, Editor        1942.0
# 4                                       Henry and Dizzy        1942.0
# ...                                                 ...           ...
# 4040                                       Sunset Trail        1939.0
# 4041                                       Sunset Trail        1939.0
# 4043                                        Lost Canyon        1943.0
# 4046                                        Fool's Gold        1947.0
# 4096  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...        2016.0
#
#          tconst titleType                                       primaryTitle  \
# 0     tt0032123     movie                                        What a Life
# 1     tt0033834     movie                                    Life with Henry
# 2     tt0033708     movie                        Henry Aldrich for President
# 3     tt0034842     movie                              Henry Aldrich, Editor
# 4     tt0034844     movie                                    Henry and Dizzy
# ...         ...       ...                                                ...
# 4040  tt0023539     movie                                       Sunset Trail
# 4041  tt0030812     movie                                       Sunset Trail
# 4043  tt0034996     movie                                        Lost Canyon
# 4046  tt0038532     movie                                        Fool's Gold
# 4096  tt6342418     movie  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...
#
#                                           originalTitle  isAdult  startYear  \
# 0                                           What a Life      0.0     1939.0
# 1                                       Life with Henry      0.0     1940.0
# 2                           Henry Aldrich for President      0.0     1941.0
# 3                                 Henry Aldrich, Editor      0.0     1942.0
# 4                                       Henry and Dizzy      0.0     1942.0
# ...                                                 ...      ...        ...
# 4040                                       Sunset Trail      0.0     1932.0
# 4041                                       Sunset Trail      0.0     1938.0
# 4043                                        Lost Canyon      0.0     1942.0
# 4046                                        Fool's Gold      0.0     1946.0
# 4096  Gekijôban Dôbutsu Sentai Jûôjâ Tai Ninninjâ Mi...      0.0     2017.0
#
#      endYear runtimeMinutes                genres  averageRating  numVotes  \
# 0         \N             75          Comedy,Drama            6.9      93.0
# 1         \N             80   Comedy,Family,Music            6.0      49.0
# 2         \N             75         Comedy,Family            6.6     146.0
# 3         \N             72   Comedy,Drama,Family            6.4     150.0
# 4         \N             71         Comedy,Family            7.2      58.0
# ...      ...            ...                   ...            ...       ...
# 4040      \N             62  Action,Music,Romance            6.2      42.0
# 4041      \N             69               Western            6.9     180.0
# 4043      \N             61               Western            6.3     161.0
# 4046      \N             63         Drama,Western            6.1     140.0
# 4096      \N             64                Action            6.9      35.0
#
#                                                    akas  \
# 0                   [What a Life, A Vida Começa aos 14]
# 1     [Life with Henry, Henry quería ir a Alaska, He...
# 2     [Henry Aldrich Para Presidente, Henry Aldrich ...
# 3             [Henry periodista, Henry Aldrich, Editor]
# 4                                     [Henry and Dizzy]
# ...                                                 ...
# 4040  [La fattoria maledetta, To monopati tou thanat...
# 4041  [Gentleman-Cowboy, Äventyret i Silver City, Ro...
# 4043  [Striden i dödsdalen, Den sorte rytter, Desfil...
# 4046  [Överfallet på guldtransporten, Twin Buttes, R...
# 4096  [Gekijôban Dôbutsu Sentai Jûôjâ Tai Ninninjâ M...
#
#                                               all_names _merge  \
# 0                                           What a Life   both
# 1                                       Life with Henry   both
# 2                           Henry Aldrich for President   both
# 3                                 Henry Aldrich, Editor   both
# 4                                       Henry and Dizzy   both
# ...                                                 ...    ...
# 4040                                       Sunset Trail   both
# 4041                                       Sunset Trail   both
# 4043                                        Lost Canyon   both
# 4046                                        Fool's Gold   both
# 4096  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...   both
#
#       difference_in_years
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 4040                  7.0
# 4041                  1.0
# 4043                  1.0
# 4046                  1.0
# 4096                  1.0
#
# [4946 rows x 19 columns]

# %%
imdb_remainder = imdb_remainder[~imdb_remainder["tconst"].isin(all_merged_both["tconst"])]

# %% [markdown]
# ### Fuzzy Matching

# %% [markdown]
# Finds the best fit for each remaining movie in the wiki dataframe

# %%
def get_top_match(row):
    return process.extractOne(row.movie_name, imdb_movie_list)

# %%
imdb_movie_list = imdb_remainder.all_names.to_list()

# %%
wiki_remainder['best_match'] = wiki_remainder.apply(lambda row: get_top_match(row), axis = 1)

# %% [markdown]
# Saves a backup of the fuzzy matching results in case any mistakes are made to avoid re-running the matching script

# %%
wiki_remainder.to_csv("backup_wiki_remainder.csv")

# %% [markdown]
# Split the result into the 3 columns below

# %%
wiki_remainder[['best_fit_title', 'best_fit_ratio', 'best_fit_game_id']] = wiki_remainder['best_match'].apply(lambda x: pd.Series([i for i in x]))
wiki_remainder
# Out:
#      franchise_id                franchise_name  \
# 11             f1                    Coffin Joe
# 15             f1                    Coffin Joe
# 27             f2                The Crime Club
# 44             f3                Fast & Furious
# 49             f4  Gingerdead Man vs. Evil Bong
# ...           ...                           ...
# 8217        f1343                  Super Sentai
# 8218        f1343                  Super Sentai
# 8219        f1343                  Super Sentai
# 8220        f1343                  Super Sentai
# 8221        f1343                  Super Sentai
#
#                                              movie_name  release_year  \
# 11                      At Midnight I'll Take Your Soul        1963.0
# 15                                       The End of Man        1970.0
# 27                                     The Last Express        1938.0
# 44                                               Fast X        2023.0
# 49                      Evil Bong 3D: The Wrath of Bong        2011.0
# ...                                                 ...           ...
# 8217  Kikai Sentai Zenkaiger vs. Kiramager vs. Senpa...        2022.0
# 8218  Avataro Sentai Donbrothers The Movie: New Firs...        2022.0
# 8219  Ninpu Sentai Hurricaneger Degozaru! Shushuuto ...        2023.0
# 8220           Avataro Sentai Donbrothers vs. Zenkaiger        2023.0
# 8221  Bakuryuu Sentai Abaranger 20th: The Unforgivab...        2023.0
#
#                                              best_match  \
# 11                              (Midnight, 90.0, 30523)
# 15                      (The End of Man, 100.0, 279988)
# 27                     (The Last Express, 100.0, 95553)
# 44                                     (X, 90.0, 42415)
# 49    (Evil Bong 3: The Wrath of Bong, 98.3606557377...
# ...                                                 ...
# 8217  (Kikai Sentai Zenkaiger vs Kiramager vs Senpai...
# 8218                            (Brothers, 90.0, 20888)
# 8219                           (Hurricane, 90.0, 24928)
# 8220                            (Brothers, 90.0, 20888)
# 8221                       (Unforgivable, 90.0, 563147)
#
#                                         best_fit_title  best_fit_ratio  \
# 11                                            Midnight       90.000000
# 15                                      The End of Man      100.000000
# 27                                    The Last Express      100.000000
# 44                                                   X       90.000000
# 49                      Evil Bong 3: The Wrath of Bong       98.360656
# ...                                                ...             ...
# 8217  Kikai Sentai Zenkaiger vs Kiramager vs Senpaiger       97.959184
# 8218                                          Brothers       90.000000
# 8219                                         Hurricane       90.000000
# 8220                                          Brothers       90.000000
# 8221                                      Unforgivable       90.000000
#
#       best_fit_game_id
# 11               30523
# 15              279988
# 27               95553
# 44               42415
# 49              991760
# ...                ...
# 8217            997090
# 8218             20888
# 8219             24928
# 8220             20888
# 8221            563147
#
# [3575 rows x 8 columns]

# %%
wiki_remainder = wiki_remainder[wiki_remainder['best_fit_ratio'].notna()]

# %% [markdown]
# Convert best_fit_game_id into int value to compare later

# %%
wiki_remainder["best_fit_game_id"] = wiki_remainder["best_fit_game_id"].apply(lambda x: int(x))

# %%
wiki_remainder[wiki_remainder["best_fit_ratio"] == 100]
# Out:
#      franchise_id                       franchise_name  \
# 15             f1                           Coffin Joe
# 27             f2                       The Crime Club
# 111           f10                        Mystery Woman
# 151           f13                            Star Wars
# 152           f54                            Star Wars
# ...           ...                                  ...
# 8017        f1340                                Santo
# 8105        f1342  Hopalong Cassidy (American-Western)
# 8130        f1342  Hopalong Cassidy (American-Western)
# 8140        f1342  Hopalong Cassidy (American-Western)
# 8204        f1343                         Super Sentai
#
#                                              movie_name  release_year  \
# 15                                       The End of Man        1970.0
# 27                                     The Last Express        1938.0
# 111                                       Mystery Woman        2003.0
# 151           Star Wars: Episode I – The Phantom Menace        1999.0
# 152           Star Wars: Episode I – The Phantom Menace        1999.0
# ...                                                 ...           ...
# 8017  Chanoc y el hijo del Santo contra los vampiros...        1981.0
# 8105                                       Sunset Trail        1939.0
# 8130                                        Lost Canyon        1943.0
# 8140                                        Fool's Gold        1947.0
# 8204  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...        2016.0
#
#                                              best_match  \
# 15                      (The End of Man, 100.0, 279988)
# 27                     (The Last Express, 100.0, 95553)
# 111                       (Mystery Woman, 100.0, 47226)
# 151   (Star Wars: Episode I - The Phantom Menace, 10...
# 152   (Star Wars: Episode I - The Phantom Menace, 10...
# ...                                                 ...
# 8017  (Chanoc y el hijo del Santo contra los vampiro...
# 8105                       (Sunset Trail, 100.0, 34301)
# 8130                        (Lost Canyon, 100.0, 83158)
# 8140                         (Fool's Gold, 100.0, 3807)
# 8204  (Doubutsu Sentai Zyuohger vs. Ninninger the Mo...
#
#                                          best_fit_title  best_fit_ratio  \
# 15                                       The End of Man           100.0
# 27                                     The Last Express           100.0
# 111                                       Mystery Woman           100.0
# 151           Star Wars: Episode I - The Phantom Menace           100.0
# 152           Star Wars: Episode I - The Phantom Menace           100.0
# ...                                                 ...             ...
# 8017  Chanoc y el hijo del Santo contra los vampiros...           100.0
# 8105                                       Sunset Trail           100.0
# 8130                                        Lost Canyon           100.0
# 8140                                        Fool's Gold           100.0
# 8204  Doubutsu Sentai Zyuohger vs. Ninninger the Mov
# [245 rows x 8 columns]

# %% [markdown]
# Only take values above 95, only taking matches that had 1 letter difference or 1 punctuation difference for example

# %%
wiki_remainder = wiki_remainder[wiki_remainder["best_fit_ratio"] > 95]

# %% [markdown]
# Merge remainders based on fuzzy matching

# %%
fuzzy_merged = pd.merge(wiki_remainder, imdb_remainder, left_on=["best_fit_game_id"], right_index=True, how="outer", indicator = True)
wiki_remainder = filter_df(fuzzy_merged, "left_only", wiki_filter)
imdb_remainder = filter_df(fuzzy_merged, "right_only", imdb_filter)
fuzzy_merged
# Out:
#      franchise_id                franchise_name  \
# 15.0           f1                    Coffin Joe
# 27.0           f2                The Crime Club
# 49.0           f4  Gingerdead Man vs. Evil Bong
# 53.0           f4  Gingerdead Man vs. Evil Bong
# 71.0           f6                    Lash LaRue
# ...           ...                           ...
# NaN           NaN                           NaN
# NaN           NaN                           NaN
# NaN           NaN                           NaN
# NaN           NaN                           NaN
# NaN           NaN                           NaN
#
#                            movie_name  release_year  \
# 15.0                   The End of Man        1970.0
# 27.0                 The Last Express        1938.0
# 49.0  Evil Bong 3D: The Wrath of Bong        2011.0
# 53.0                Evil Bong High-5!        2016.0
# 71.0                 Son of a Bad Man        1949.0
# ...                               ...           ...
# NaN                               NaN           NaN
# NaN                               NaN           NaN
# NaN                               NaN           NaN
# NaN                               NaN           NaN
# NaN                               NaN           NaN
#
#                                              best_match  \
# 15.0                    (The End of Man, 100.0, 279988)
# 27.0                   (The Last Express, 100.0, 95553)
# 49.0  (Evil Bong 3: The Wrath of Bong, 98.3606557377...
# 53.0    (Evil Bong: High 5, 96.96969696969697, 1152092)
# 71.0        (Son of a Badman, 96.7741935483871, 117172)
# ...                                                 ...
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                       best_fit_title  best_fit_ratio  best_fit_game_id  \
# 15.0                  The End of Man      100.000000            279988
# 27.0                The Last Express      100.000000             95553
# 49.0  Evil Bong 3: The Wrath of Bong       98.360656            991760
# 53.0               Evil Bong: High 5       96.969697           1152092
# 71.0                 Son of a Badman       96.774194            117172
# ...                              ...             ...               ...
# NaN                              NaN             NaN           1340959
# NaN                              NaN             NaN           1340960
# NaN                              NaN             NaN           1340961
# NaN                              NaN             NaN           1340962
# NaN                              NaN             NaN           1340963
#
#           tconst titleType  ... isAdult startYear  endYear  runtimeMinutes  \
# 15.0   tt0063704     movie  ...     0.0    1968.0       \N              91
# 27.0   tt0035082     movie  ...     0.0    1942.0       \N              94
# 49.0  tt14354838     movie  ...     0.0    2021.0       \N              94
# 53.0   tt3113296     movie  ...     0.0    2014.0       \N              80
# 71.0   tt0039348     movie  ...     0.0    1948.0       \N             100
# ...          ...       ...  ...     ...       ...      ...             ...
# NaN    tt9916428     movie  ...     0.0    2019.0       \N              \N
# NaN    tt9916428     movie  ...     0.0    2019.0       \N              \N
# NaN    tt9916538     movie  ...     0.0    2019.0       \N             123
# NaN    tt9916730     movie  ...     0.0    2017.0       \N             116
# NaN    tt9916730     movie  ...     0.0    2017.0       \N             116
#
#                      genres averageRating numVotes  \
# 15.0               Thriller           6.0    195.0
# 27.0  Crime,Drama,Film-Noir           6.8   2034.0
# 49.0            Documentary           7.5    704.0
# 53.0            Documentary           7.0     10.0
# 71.0          Drama,Fantasy           6.6     68.0
# ...                     ...           ...      ...
# NaN   Adventure,History,War           3.8     14.0
# NaN   Adventure,History,War           3.8     14.0
# NaN                   Drama           8.6      7.0
# NaN                      \N           8.3     10.0
# NaN                      \N           8.3     10.0
#
#                                                    akas  \
# 15.0  [L'homme à la jaguar rouge, La morte in jaguar...
# 27.0  [La péniche de l'amour, Apokliroi tis zois, St...
# 49.0  [Héroes. Silencio y Rock & Roll, Héroes del Si...
# 53.0                                [Pequeña Babilonia]
# 71.0  [El judio errante, Den evige jøde, O Homem Sem...
# ...                                                 ...
# NaN   [The Secret of China, Hong xing zhao yao Zhong...
# NaN   [The Secret of China, Hong xing zhao yao Zhong...
# NaN                               [Kuambil Lagi Hatiku]
# NaN                                     [६ गुण, 6 Gunn]
# NaN                                     [६ गुण, 6 Gunn]
#
#                                        all_names      _merge
# 15.0                       Death in a Red Jaguar        both
# 27.0                              Nocny przypływ        both
# 49.0  Héroes del Silencio: Barulho e Rock'n'Roll        both
# 53.0                           Pequeña Babilonia        both
# 71.0                        Vaeltava juutalainen        both
# ...                                          ...         ...
# NaN                          The Secret of China  right_only
# NaN                 Hong xing zhao yao Zhong guo  right_only
# NaN                          Kuambil Lagi Hatiku  right_only
# NaN                                        ६ गुण  right_only
# NaN                                       6 Gunn  right_only
#
# [1271636 rows x 22 columns]

# %%
fuzzy_merged = fuzzy_merged[fuzzy_merged["_merge"]=="both"]
fuzzy_merged = fuzzy_merged.drop_duplicates(subset = "tconst",keep = "first")
fuzzy_merged["tconst"].nunique()
# Out:
# 787

# %% [markdown]
# Filter by year

# %%
fuzzy_merged['difference_in_years'] = fuzzy_merged.apply(lambda x: abs(x['startYear'] - x['release_year']), axis=1)
fuzzy_merged = fuzzy_merged[fuzzy_merged["difference_in_years"] <= 10]
fuzzy_merged["tconst"].nunique()
# Out:
# 545

# %%
matched = pd.concat([matched, fuzzy_merged])
matched = matched[matched["_merge"]=="both"]
matched
# Out:
#        franchise_id      franchise_name  \
# 0.0              f0  The Aldrich Family
# 1.0              f0  The Aldrich Family
# 2.0              f0  The Aldrich Family
# 3.0              f0  The Aldrich Family
# 4.0              f0  The Aldrich Family
# ...             ...                 ...
# 8197.0        f1343        Super Sentai
# 8202.0        f1343        Super Sentai
# 8204.0        f1343        Super Sentai
# 8214.0        f1343        Super Sentai
# 8217.0        f1343        Super Sentai
#
#                                                movie_name  release_year  \
# 0.0                                           What a Life        1939.0
# 1.0                                       Life with Henry        1940.0
# 2.0                           Henry Aldrich for President        1941.0
# 3.0                                 Henry Aldrich, Editor        1942.0
# 4.0                                       Henry and Dizzy        1942.0
# ...                                                   ...           ...
# 8197.0  Heisei Riders vs. Shōwa Riders: Kamen Rider Ta...        2014.0
# 8202.0  Shuriken Sentai Ninninger vs. ToQger the Movie...        2016.0
# 8204.0  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...        2016.0
# 8214.0             Mashin Sentai Kiramager vs. Ryusoulger        2021.0
# 8217.0  Kikai Sentai Zenkaiger vs. Kiramager vs. Senpa...        2022.0
#
#             tconst titleType                       primaryTitle  \
# 0.0      tt0032123     movie                        What a Life
# 1.0      tt0033834     movie                    Life with Henry
# 2.0      tt0033708     movie        Henry Aldrich for President
# 3.0      tt0034842     movie              Henry Aldrich, Editor
# 4.0      tt0034844     movie                    Henry and Dizzy
# ...            ...       ...                                ...
# 8197.0   tt2241691     movie                  Under the Rainbow
# 8202.0   tt3355274     movie            Così parlò De Crescenzo
# 8204.0   tt4257950     movie                    Russell Madness
# 8214.0  tt11708788     movie                   Mecca I'm Coming
# 8217.0  tt14586644     movie  Keith Richards: You Can't Rock Me
#
#                             originalTitle  isAdult  startYear  ...  \
# 0.0                           What a Life      0.0     1939.0  ...
# 1.0                       Life with Henry      0.0     1940.0  ...
# 2.0           Henry Aldrich for President      0.0     1941.0  ...
# 3.0                 Henry Aldrich, Editor      0.0     1942.0  ...
# 4.0                       Henry and Dizzy      0.0     1942.0  ...
# ...                                   ...      ...        ...  ...
# 8197.0                   Au bout du conte      0.0     2013.0  ...
# 8202.0            Così parlò De Crescenzo      0.0     2016.0  ...
# 8204.0                    Russell Madness      0.0     2015.0  ...
# 8214.0                   Mekah I'm Coming      0.0     2019.0  ...
# 8217.0  Keith Richards: You Can't Rock Me      0.0     2019.0  ...
#
#        averageRating numVotes  \
# 0.0              6.9     93.0
# 1.0              6.0     49.0
# 2.0              6.6    146.0
# 3.0              6.4    150.0
# 4.0              7.2     58.0
# ...              ...      ...
# 8197.0           5.8   1393.0
# 8202.0           7.8     77.0
# 8204.0           4.2    684.0
# 8214.0           7.6     99.0
# 8217.0           6.5      6.0
#
#                                                      akas  \
# 0.0                   [What a Life, A Vida Começa aos 14]
# 1.0     [Life with Henry, Henry quería ir a Alaska, He...
# 2.0     [Henry Aldrich Para Presidente, Henry Aldrich ...
# 3.0             [Henry periodista, Henry Aldrich, Editor]
# 4.0                                     [Henry and Dizzy]
# ...                                                   ...
# 8197.0  [Au bout du conte, Under regnbuen, Książę nie ...
# 8202.0  [Così parlò De Crescenzo, I Am an Unemployed E...
# 8204.0  [Russell Madness, Chú Chó Đô Vật, Безумие Расс...
# 8214.0  [Mekah I'm Coming, Mecca, I'm Coming, Mecca I'...
# 8217.0                [Keith Richards: You Can't Rock Me]
#
#                                 all_names  _merge difference_in_years  \
# 0.0                           What a Life    both                 NaN
# 1.0                       Life with Henry    both                 NaN
# 2.0           Henry Aldrich for President    both                 NaN
# 3.0                 Henry Aldrich, Editor    both                 NaN
# 4.0                       Henry and Dizzy    both                 NaN
# ...                                   ...     ...                 ...
# 8197.0                   Френска приказка    both                 1.0
# 8202.0      Sono un ingegnere disoccupato    both                 0.0
# 8204.0                   Russell Wahnsinn    both                 1.0
# 8214.0                   Mekah I'm Coming    both                 2.0
# 8217.0  Keith Richards: You Can't Rock Me    both                 3.0
#
#                                                best_match  \
# 0.0                                                   NaN
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# ...                                                   ...
# 8197.0  (Heisei Rider vs. Showa Rider: Kamen Rider Tai...
# 8202.0  (Shuriken Sentai Ninninger vs. ToQger the Movi...
# 8204.0  (Doubutsu Sentai Zyuohger vs. Ninninger the Mo...
# 8214.0  (Mashin Sentai Kiramager vs Ryusoulger, 98.666...
# 8217.0  (Kikai Sentai Zenkaiger vs Kiramager vs Senpai...
#
#                                            best_fit_title  best_fit_ratio  \
# 0.0                                                   NaN             NaN
# 1.0                                                   NaN             NaN
# 2.0                                                   NaN             NaN
# 3.0                                                   NaN             NaN
# 4.0                                                   NaN             NaN
# ...                                                   ...             ...
# 8197.0  Heisei Rider vs. Showa Rider: Kamen Rider Tais...       97.058824
# 8202.0  Shuriken Sentai Ninninger vs. ToQger the Movie...       99.259259
# 8204.0  Doubutsu Sentai Zyuohger vs. Ninninger the Mov...      100.000000
# 8214.0              Mashin Sentai Kiramager vs Ryusoulger       98.666667
# 8217.0   Kikai Sentai Zenkaiger vs Kiramager vs Senpaiger       97.959184
#
#        best_fit_game_id
# 0.0                 NaN
# 1.0                 NaN
# 2.0                 NaN
# 3.0                 NaN
# 4.0                 NaN
# ...                 ...
# 8197.0        1102455.0
# 8202.0        1162698.0
# 8204.0        1197391.0
# 8214.0         927510.0
# 8217.0         997090.0
#
# [5491 rows x 23 columns]

# %% [markdown]
# Trim complete dataframe

# %%
matched = matched[["franchise_id", "franchise_name", "movie_name", "tconst", "primaryTitle", "isAdult", "release_year", "runtimeMinutes", "genres", "averageRating", "numVotes"]]

# %%
matched

# %%
wiki_remainder

# %%
matched.columns = matched.columns.str.replace('release_year', 'startYear')

# %% [markdown]
# Merge matched dataframe with all movies left in IMDB
#
# *This was done with the intention of examining non-franchised movies in a research question that was later cut*

# %%
imdb_final = pd.merge(matched, imdb_movies, on = "tconst", how = "outer")
imdb_final
# Out:
#         franchise_id      franchise_name       movie_name     tconst  \
# 0                 f0  The Aldrich Family      What a Life  tt0032123
# 1                 f0  The Aldrich Family      What a Life  tt0032123
# 2                 f0  The Aldrich Family  Life with Henry  tt0033834
# 3                 f0  The Aldrich Family  Life with Henry  tt0033834
# 4                 f0  The Aldrich Family  Life with Henry  tt0033834
# ...              ...                 ...              ...        ...
# 1337336          NaN                 NaN              NaN  tt9916428
# 1337337          NaN                 NaN              NaN  tt9916428
# 1337338          NaN                 NaN              NaN  tt9916538
# 1337339          NaN                 NaN              NaN  tt9916730
# 1337340          NaN                 NaN              NaN  tt9916730
#
#           primaryTitle_x  isAdult_x  startYear_x runtimeMinutes_x  \
# 0            What a Life        0.0       1939.0               75
# 1            What a Life        0.0       1939.0               75
# 2        Life with Henry        0.0       1940.0               80
# 3        Life with Henry        0.0       1940.0               80
# 4        Life with Henry        0.0       1940.0               80
# ...                  ...        ...          ...              ...
# 1337336              NaN        NaN          NaN              NaN
# 1337337              NaN        NaN          NaN              NaN
# 1337338              NaN        NaN          NaN              NaN
# 1337339              NaN        NaN          NaN              NaN
# 1337340              NaN        NaN          NaN              NaN
#
#                     genres_x  averageRating_x  ...  \
# 0               Comedy,Drama              6.9  ...
# 1               Comedy,Drama              6.9  ...
# 2        Comedy,Family,Music              6.0  ...
# 3        Comedy,Family,Music              6.0  ...
# 4        Comedy,Family,Music              6.0  ...
# ...                      ...              ...  ...
# 1337336                  NaN              NaN  ...
# 1337337                  NaN              NaN  ...
# 1337338                  NaN              NaN  ...
# 1337339                  NaN              NaN  ...
# 1337340                  NaN              NaN  ...
#
#                         originalTitle isAdult_y startYear_y endYear  \
# 0                         What a Life         0        1939      \N
# 1                         What a Life         0        1939      \N
# 2                     Life with Henry         0        1940      \N
# 3                     Life with Henry         0        1940      \N
# 4                     Life with Henry         0        1940      \N
# ...                               ...       ...         ...     ...
# 1337336  Hong xing zhao yao Zhong guo         0        2019      \N
# 1337337  Hong xing zhao yao Zhong guo         0        2019      \N
# 1337338           Kuambil Lagi Hatiku         0        2019      \N
# 1337339                        6 Gunn         0        2017      \N
# 1337340                        6 Gunn         0        2017      \N
#
#          runtimeMinutes_y               genres_y averageRating_y numVotes_y  \
# 0                      75           Comedy,Drama             6.9       93.0
# 1                      75           Comedy,Drama             6.9       93.0
# 2                      80    Comedy,Family,Music             6.0       49.0
# 3                      80    Comedy,Family,Music             6.0       49.0
# 4                      80    Comedy,Family,Music             6.0       49.0
# ...                   ...                    ...             ...        ...
# 1337336                \N  Adventure,History,War             3.8       14.0
# 1337337                \N  Adventure,History,War             3.8       14.0
# 1337338               123                  Drama             8.6        7.0
# 1337339               116                     \N             8.3       10.0
# 1337340               116                     \N             8.3       10.0
#
#                                                       akas  \
# 0                      [What a Life, A Vida Começa aos 14]
# 1                      [What a Life, A Vida Começa aos 14]
# 2        [Life with Henry, Henry quería ir a Alaska, He...
# 3        [Life with Henry, Henry quería ir a Alaska, He...
# 4        [Life with Henry, Henry quería ir a Alaska, He...
# ...                                                    ...
# 1337336  [The Secret of China, Hong xing zhao yao Zhong...
# 1337337  [The Secret of China, Hong xing zhao yao Zhong...
# 1337338                              [Kuambil Lagi Hatiku]
# 1337339                                    [६ गुण, 6 Gunn]
# 1337340                                    [६ गुण, 6 Gunn]
#
#                             all_names
# 0                A Vida Começa aos 14
# 1                         What a Life
# 2            Henry quería ir a Alaska
# 3              Henry Está na Berlinda
# 4                     Life with Henry
# ...                               ...
# 1337336           The Secret of China
# 1337337  Hong xing zhao yao Zhong guo
# 1337338           Kuambil Lagi Hatiku
# 1337339                         ६ गुण
# 1337340                        6 Gunn
#
# [1337341 rows x 23 columns]

# %% [markdown]
# Filters out duplicate columns

# %%
imdb_final = imdb_final[["franchise_id", "franchise_name", "movie_name", "tconst", "primaryTitle_y", "isAdult_y", "startYear_y", "runtimeMinutes_y", "genres_y", "averageRating_y", "numVotes_y"]]
imdb_final
# Out:
#         franchise_id      franchise_name       movie_name     tconst  \
# 0                 f0  The Aldrich Family      What a Life  tt0032123
# 1                 f0  The Aldrich Family      What a Life  tt0032123
# 2                 f0  The Aldrich Family  Life with Henry  tt0033834
# 3                 f0  The Aldrich Family  Life with Henry  tt0033834
# 4                 f0  The Aldrich Family  Life with Henry  tt0033834
# ...              ...                 ...              ...        ...
# 1337336          NaN                 NaN              NaN  tt9916428
# 1337337          NaN                 NaN              NaN  tt9916428
# 1337338          NaN                 NaN              NaN  tt9916538
# 1337339          NaN                 NaN              NaN  tt9916730
# 1337340          NaN                 NaN              NaN  tt9916730
#
#               primaryTitle_y  isAdult_y  startYear_y runtimeMinutes_y  \
# 0                What a Life          0         1939               75
# 1                What a Life          0         1939               75
# 2            Life with Henry          0         1940               80
# 3            Life with Henry          0         1940               80
# 4            Life with Henry          0         1940               80
# ...                      ...        ...          ...              ...
# 1337336  The Secret of China          0         2019               \N
# 1337337  The Secret of China          0         2019               \N
# 1337338  Kuambil Lagi Hatiku          0         2019              123
# 1337339               6 Gunn          0         2017              116
# 1337340               6 Gunn          0         2017              116
#
#                       genres_y  averageRating_y  numVotes_y
# 0                 Comedy,Drama              6.9        93.0
# 1                 Comedy,Drama              6.9        93.0
# 2          Comedy,Family,Music              6.0        49.0
# 3          Comedy,Family,Music              6.0        49.0
# 4          Comedy,Family,Music              6.0        49.0
# ...                        ...              ...         ...
# 1337336  Adventure,History,War              3.8        14.0
# 1337337  Adventure,History,War              3.8        14.0
# 1337338                  Drama              8.6         7.0
# 1337339                     \N              8.3        10.0
# 1337340                     \N              8.3        10.0
#
# [1337341 rows x 11 columns]

# %% [markdown]
# Cleans up column names

# %%
imdb_final.columns = imdb_final.columns.str.replace('primaryTitle_y', 'primaryTitle')
imdb_final.columns = imdb_final.columns.str.replace('isAdult_y', 'isAdult')
imdb_final.columns = imdb_final.columns.str.replace('startYear_y', 'startYear')
imdb_final.columns = imdb_final.columns.str.replace('runtimeMinutes_y', 'runtimeMinutes')
imdb_final.columns = imdb_final.columns.str.replace('genres_y', 'genres')
imdb_final.columns = imdb_final.columns.str.replace('averageRating_y', 'averageRating')
imdb_final.columns = imdb_final.columns.str.replace('numVotes_y', 'numVotes')

# %%
wiki_remainder["franchise_name"].nunique()
# Out:
# 41

# %%
imdb_final["franchise_id"].nunique()
# Out:
# 1142

# %% [markdown]
# Export to csv

# %%
imdb_final.to_csv("clean_movies_with_franchises.csv")

# %% [markdown]
# # Test Code

# %%
imdb_final[imdb_final["primaryTitle"] == "iron man"]

# %%
wiki_remainder[wiki_remainder["franchise_name"] == "DC Extended Universe"]

# %%
test = imdb_remainder.sort_values("numVotes", ascending = False).drop_duplicates(subset=["tconst"], keep="first").sort_values(["tconst"])
test[test["numVotes"] >292]

# %%
imdb_final[imdb_final["franchise_id"].isnull]

# %%
test = pd.isnull(imdb_final["franchise_id"])
imdb_final[test]["numVotes"].describe()

# %%
test = pd.notnull(imdb_final["franchise_id"])
imdb_final[test]["numVotes"].describe()

# %% [markdown]
# # Unused code

# %%
# apply this mask function at each step of the matching process and see how many found rows there are
list1 = list(matched["index"])
found_mask = []
for i in range(0, len(list(wiki_movies["index"]))):
    if i in list1:
        found_mask.append(True)
    else:
        found_mask.append(False)
    
#print(list1)
print(wiki_movies[found_mask])

# %%
both_test = matched[matched["_merge"]=="both"].sort_values(by = "index")

# %%
# look into moving all names into one list, then searching with date
# With remainder, search without date and see what happens

# %%
# losing some values in both data frames for unknown reason when using merge.
# starts with 6405 rows in wiki and 290239 rows in imdb
# 3307 
#              wiki  |  imdb 
# start     |  6405  |  290239
# found     |  3088  |    3088
# remaining |  3307  |  287199
# total     |  6395  |  290287
# variance  |   -10  |     +48
